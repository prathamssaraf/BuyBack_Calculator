# %%
from annual_report_downloader import process_annual_report
from data_extractor import convert_images_to_csv
from current_price import get_last_closing_price
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ask the user to enter the company symbol
company_symbol = "SIYSIL"

# %% [markdown]
# # Extracting Data from Annual Reports

# %%
years_to_process = ["2023", "2022", "2021", "2020"]  # Adjust the years as needed

# Initialize a list to store the pages with phrases for each year
pages_with_phrases = []

# Initialize a list to store the image file names for each year
image_file_names = []

# Loop over the years and process the annual reports
for year in years_to_process:
    print(f"Processing annual report for {year}...")
    process_annual_report(company_symbol, year, pages_with_phrases)
    image_file_names.append(f"{company_symbol}_Annual_Report_{year}_Shareholding.PNG")
    print(f"Finished processing annual report for {year}")

# Display all the saved images at the end
num_images = len(image_file_names)
fig, axes = plt.subplots(1, num_images, figsize=(16, 4))

for i in range(num_images):
    image = plt.imread(image_file_names[i])
    axes[i].imshow(image)
    axes[i].set_title(f"Year {years_to_process[i]}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Processing annual report for 2023...
# Link: https://www.bseindia.com/xml-data/corpfiling/AttachHis//0609f3e3-e176-4f84-ae03-3926593ebde7.pdf
# Saved the PDF as 'SIYSIL_Annual_Report_2023.pdf' successfully.
# The phrases were found on pages: 106
# Finished processing annual report for 2023
# Processing annual report for 2022...
# Link: https://www.bseindia.com/bseplus/AnnualReport/503811/73334503811.pdf
# Saved the PDF as 'SIYSIL_Annual_Report_2022.pdf' successfully.
# The phrases were found on pages: 60
# Finished processing annual report for 2022
# Processing annual report for 2021...
# Link: https://www.bseindia.com/bseplus/AnnualReport/503811/68792503811.pdf
# Saved the PDF as 'SIYSIL_Annual_Report_2021.pdf' successfully.
# The phrases were found on pages: 44
# Finished processing annual report for 2021
# Processing annual report for 2020...
# Link: https://www.bseindia.com/bseplus/AnnualReport/503811/5038110320.pdf
# Saved the PDF as 'SIYSIL_Annual_Report_2020.pdf' successfully.
# The phrases were found on pages: 47
# Finished processing annual report for 2020

# %% [markdown]
# # Converting it to CSV format and storing in DataFrames

# %%
years_to_process = ["2022", "2021", "2020"]
convert_images_to_csv(company_symbol, years_to_process)
# Out:
# Image 'SIYSIL_Annual_Report_2022_Shareholding.PNG' converted to PDF: 'SIYSIL_Annual_Report_Data_2022.pdf'
# Tables extracted from PDF 'SIYSIL_Annual_Report_Data_2022.pdf' and saved to 'SIYSIL_Annual_Report_2022_Shareholding.xlsx'
# XLSX 'SIYSIL_Annual_Report_2022_Shareholding.xlsx' converted to CSV: 'SIYSIL_2022_Shareholding.csv'
# PDF 'SIYSIL_Annual_Report_Data_2022.pdf' and XLSX 'SIYSIL_Annual_Report_2022_Shareholding.xlsx' deleted after conversion
# Image 'SIYSIL_Annual_Report_2021_Shareholding.PNG' converted to PDF: 'SIYSIL_Annual_Report_Data_2021.pdf'
# Tables extracted from PDF 'SIYSIL_Annual_Report_Data_2021.pdf' and saved to 'SIYSIL_Annual_Report_2021_Shareholding.xlsx'
# XLSX 'SIYSIL_Annual_Report_2021_Shareholding.xlsx' converted to CSV: 'SIYSIL_2021_Shareholding.csv'
# PDF 'SIYSIL_Annual_Report_Data_2021.pdf' and XLSX 'SIYSIL_Annual_Report_2021_Shareholding.xlsx' deleted after conversion
# Image 'SIYSIL_Annual_Report_2020_Shareholding.PNG' converted to PDF: 'SIYSIL_Annual_Report_Data_2020.pdf'
# Tables extracted from PDF 'SIYSIL_Annual_Report_Data_2020.pdf' and saved to 'SIYSIL_Annual_Report_2020_Shareholding.xlsx'
# XLSX 'SIYSIL_Annual_Report_2020_Shareholding.xlsx' converted to CSV: 'SIYSIL_2020_Shareholding.csv'
# PDF 'SIYSIL_Annual_Report_Data_2020.pdf' and XLSX 'SIYSIL_Annual_Report_2020_Shareholding.xlsx' deleted after conversion
